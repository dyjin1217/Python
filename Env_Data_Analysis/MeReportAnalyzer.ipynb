# %%
import pandas as pd
import re
import gensim 
import mglearn
import numpy as np
import os
import matplotlib.pyplot as plt
from konlpy.utils import pprint
from konlpy.tag import Hannanum
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import LatentDirichletAllocation
from konlpy.tag import Kkma, Twitter
import pyLDAvis.gensim
import pyLDAvis.sklearn
import collections


class MeReportAnalyzer():
    
        def __init__ (self):
            self.idx_result_df = pd.DataFrame()
            input_file_name = '/media/MeReportCrawler/result/indexing.txt'
            
            
            self.idx_result_df = pd.read_csv(input_file_name,header=None)
            self.filtered_idx_result_df = pd.DataFrame()
            self.idx_result_df.columns = ['date','title','content_url_list','file_list']
            
            self.climate_words = ["기후","온실가스","온난화","이산화탄소","탄소","폭설","폭우",
                                  "폭설","홍수","가뭄","혹서","혹한","해수면","열섬","이상고온","집중호우","해일","쓰나미","북극빙하","남극빙하",
                                  "히말라야빙하","그린란드빙하","사막화","녹색성장","태풍"]
            
            self.document_topics = None
            self.topic_words = None
            self.filtered_sentences = None
            
            #디렉토리 생성
            dirname = 'result'
            if ((os.path.isdir('./' + dirname + '/')) == False):
                os.mkdir('./' + dirname + '/')
      
            dirname = 'lda_result'
            if ((os.path.isdir('./' + dirname + '/')) == False):
                os.mkdir('./' + dirname + '/')
                
            dirname = 'tm_result'
            if ((os.path.isdir('./' + dirname + '/')) == False):
                os.mkdir('./' + dirname + '/')    
                
            self.idx_result_df['date'] = list(map(str, self.idx_result_df['date']))   
            self.idx_result_df['file_list'] = list(map(lambda x: os.path.dirname(input_file_name) + "/" + os.path.basename(x), self.idx_result_df['file_list'].tolist()))
            
            self.filtered_idx_result_df =  self.idx_result_df  
            
        def filtering_date(self,start_date = None, end_date = None):
            dt_index = pd.date_range(start=start_date, end = end_date)
            dt_list = dt_index.strftime("%Y-%m-%d").tolist()
            idx = list(map(lambda x: x in dt_list, self.idx_result_df['date'].tolist()))
            self.filtered_idx_result_df = self.filtered_idx_result_df.iloc[idx]
            self.filtered_idx_result_df = self.filtered_idx_result_df.reset_index(drop=True)
            #print(self.idx_result_df[self.idx_result_df['date'] in dt_list])
        
        def trend_analysis(self, prefix="", is_relative=False):     
            dt_list = ma.filtered_idx_result_df['date'].tolist()
            dt_cnt = collections.Counter(list(map(lambda x : x.split("-")[0], dt_list)))
            # = list(b)
            x = list(dt_cnt.keys())
            
            if(is_relative == True)
                 all_dt_list = self.idx_result_df['date']
                
            y = list(dt_cnt.values())
            plt.xticks(rotation=50)
            plt.plot(x,y,c="b", lw=3, ls="--", marker="o", ms=10, mec="g", mew=3, mfc="r")
            plt.savefig("./" + prefix + "trends.png",dpi=200)

            
        def filtering_contents(self,rexp):
            
            file_list =  self.filtered_idx_result_df['file_list'].tolist()
            #print(file_list)
            fidx = []
            for i in range(len(file_list)):
                f = open(file_list[i], 'r',encoding='utf-8',errors="ignore")
                doc = f.read()
                p = re.compile(rexp)

                ridx = p.search(doc)

                if(ridx == None):
                   #print("없음")
                    continue
                fidx.append(i)
            #print(fidx)
            self.filtered_idx_result_df = self.filtered_idx_result_df.iloc[fidx]
            self.filtered_idx_result_df = self.filtered_idx_result_df.reset_index(drop=True)
            #print(self.idx_result_df)
        
        def reflect_result(self):
            self.idx_result_df = self.filtered_idx_result_df
            
        def save_filtered_result(self):
            self.idx_result_df.to_csv("./result/findexing.txt",header=None,index=None)
        
        def topic_modeling(self,n_topics,postfix="",is_pa=True):
            
            # 형태소 분석을 기본적으로 수행 
            
            if is_pa == True :
                file_list = self.filtered_idx_result_df['file_list'].tolist()
                #print(file_list)
                corpus = []
                
                # 형태소 분석기 선택
                #kkma = Kkma()
                kkma = Twitter()
                
                # 파일 내용 읽어서 코퍼스에 저장 
                
                for i in range(len(file_list)):
                    #print(i)
                    f = open(file_list[i], 'r',encoding='utf-8',errors="ignore")
                    doc = f.read()                       
                    corpus.append(" ".join(kkma.nouns(doc)))

                #print(corpus)

                # Stop words ,
                stop_words = ["전략", "연구", "평가", "마련", "조사", "관리", "보다", "분석", "구축","개발","정책","대책",
                              "관련","전문가","예정","이번","환경부", "환경", "기술", "사업", "산업", "기업","우리나라", "또한",
                              "총회", "대한", "통해", "한국","국내","개최","행사","우수","서울","장관","호남권","피해","해외","일자리","박람회",
                              "지원", "위해", "총회","국제","분야","환경기술"]
                vect = CountVectorizer(stop_words = stop_words,ngram_range=(1, 2),min_df=0.005,max_df=0.3)
                X = vect.fit_transform(corpus)
                X = TfidfTransformer().fit_transform(X)

                #vect = CountVectorizer(stop_words = stop_words,min_df=0.005,max_df=0.3)
         
            n_words = 20
            for i in n_topics:
                lda = LatentDirichletAllocation(n_components = i,learning_method="batch",random_state=1)
                #lda = LatentDirichletAllocation(learning_method="batch")
                self.document_topics = lda.fit_transform(X)
                
                sorting = np.argsort(lda.components_, axis=1)[:,::-1]
                feature_names = np.array(vect.get_feature_names())
                #mglearn.tools.print_topics(topics=range(i), feature_names = feature_names, sorting=sorting, topics_per_chunk=20, n_words=20)
            
                self.filtered_idx_result_df["topic"] = np.argmax(ma.document_topics,axis=1).tolist()
                self.topic_words = pd.DataFrame(feature_names[sorting])
                self.topic_words = self.topic_words.T
                self.topic_words = self.topic_words[:n_words]
                # 파일이름 접두사
                prefix = "./tm_result/result_n_" + str(i) + "_" + str(postfix)
                
                # 파일 저장 
                self.save_result(prefix)
                self.topic_modeling_vis(lda, X, vect,"result_n_" + str(i) + "_" + str(postfix) + "_")
        
        def topic_modeling_vis(self,lda,dtm,vect,prefix):
            pyldavis = pyLDAvis.sklearn.prepare(lda, dtm,vect)
            pyLDAvis.save_html(pyldavis,"./lda_vis/" + prefix + "lda.html")
                               
        def save_result(self,prefix):
            self.idx_result_df.to_csv(prefix + "_document_topic.csv",header=None,index=False)
            self.topic_words.to_csv(prefix + "_topic_words.csv",header=None,index=False)
            
        def select_topic_by_keywords(self,topics,proprtions=0.3):
            topic_list = self.filtered_idx_result_df['topic'].tolist()
            self.filtered_idx_result_df = self.filtered_idx_result_df.iloc[list(map(lambda x: x in topics, topic_list)),:]
            self.filtered_idx_result_df = self.filtered_idx_result_df.reset_index(drop=True)
            
        def select_topic(self,topics):
            topic_list = self.filtered_idx_result_df['topic'].tolist()
            self.filtered_idx_result_df = self.filtered_idx_result_df.iloc[list(map(lambda x: x in topics, topic_list)),:]
            self.filtered_idx_result_df = self.filtered_idx_result_df.reset_index(drop=True)
            
        def keyword_analysis(self,num,is_tfidf = True):
            file_list = self.filtered_idx_result_df['file_list'].tolist()
            print(len(file_list))
            print("Keyword Analysis")
            corpus = []
                
            # 형태소 분석기 선택
            #kkma = Kkma()
            kkma = Twitter()

            # 파일 내용 읽어서 코퍼스에 저장 

            for i in range(len(file_list)):
                #print(i)
                f = open(file_list[i], 'r',encoding='utf-8',errors="ignore")
                doc = f.read()                       
                corpus.append(" ".join(kkma.nouns(doc)))

            stop_words = []
                    
            vect = CountVectorizer(stop_words = stop_words,ngram_range=(1, 2),min_df=0.005,max_df=0.3)
            #ocab = vectorizer.get_feature_names()
            
            X = vect.fit_transform(corpus)
            if(is_tfidf == True):
                X = TfidfTransformer().fit_transform(X)
                
            count = X.toarray().sum(axis=0)
            idx = np.argsort(-count)
            count = count[idx]
     
            feature_name = np.array(vect.get_feature_names())[idx]
            plt.bar(range(len(count)), count)
            plt.show()
            
            pprint(list(zip(feature_name[:num], count[:num])))
            
        def extract_sentence(self,rexp):
            file_list =  self.filtered_idx_result_df['file_list'].tolist()
            filtered_sentences= []
            for i in range(len(file_list)):
                f = open(file_list[i], 'r',encoding='utf-8',errors="ignore")
                doc = f.read()
                sentences = self.split_text(doc)
                
                for s in sentences :
                    p = re.compile(rexp)
                    ridx = p.search(s)

                    if(ridx == None):
                       #print("없음")
                        continue
                    filtered_sentences.append(s.strip())
            
            self.filtered_sentences = filtered_sentences
            
        def sentence_keyword_analysis(self):
            kkma = Twitter()
            corpus = []
            
            for s in self.filtered_sentences:               
                corpus.append(" ".join(kkma.nouns(s)))

            # Stop words ,
            stop_words = ["전략", "연구", "평가", "마련", "조사", "관리", "보다", "분석", "구축","개발","정책","대책",
                          "관련","전문가","예정","이번","환경부", "환경", "기술", "사업", "산업", "기업","우리나라", "또한",
                          "총회", "대한", "통해", "한국","국내","개최","행사","우수","서울","장관","호남권","피해","해외","일자리","박람회",
                          "지원", "위해", "총회","국제","분야","환경기술"]
                    
            vect = CountVectorizer(stop_words = stop_words,ngram_range=(1, 2),min_df=0.005,max_df=0.3)
            #ocab = vectorizer.get_feature_names()
            
            X = vect.fit_transform(corpus)
            X = TfidfTransformer().fit_transform(X)
            count = X.toarray().sum(axis=0)
            idx = np.argsort(-count)
            count = count[idx]
     
            feature_name = np.array(vect.get_feature_names())[idx]
            plt.bar(range(len(count)), count)
            plt.show()
            
            pprint(list(zip(feature_name, count)))
            
        def split_text(self,text):
            new_text = text.replace(".",".\n").replace("?","?\n").replace("!","!\n")
            sentences = new_text.splitlines()
            return sentences 
                           
        def combine_result(self,s):
            print("AA")

# %%
ma = MeReportAnalyzer()
ma.filtering_date('2005-01-01','2017-12-31')
ma.filtered_idx_result_df.tail(3)

#ma.extract_sentence("기후변화")
#ma.sentence_keyword_analysis()

#ma.filtering_contents("기후변화")

#ma.topic_modeling([20],"s1")
#ma.select_topic([1])
#ma.filtered_idx_result_df


#ma.topic_modeling([40],"s1")

#ma.filtered_idx_result_df
#ma.topic_words
# Out:
#             date                                    title  \
# 9081  2017-12-29  (참고) 연휴 앞둔 12월 29일 수도권 미세먼지 비상저감조치 첫 발령
# 9082  2017-12-29              익산 장점마을과 인천 사월마을, 건강영향조사 착수
# 9083  2017-12-29                   국립공원, 해맞이·해넘이 명소 6곳 선정
#
#                                        content_url_list  \
# 9081  http://www.me.go.kr/home/web/board/read.do;jse...
# 9082  http://www.me.go.kr/home/web/board/read.do;jse...
# 9083  http://www.me.go.kr/home/web/board/read.do;jse...
#
#                                          file_list
# 9081  /media/MeReportCrawler/result/20171229_1.txt
# 9082  /media/MeReportCrawler/result/20171229_3.txt
# 9083  /media/MeReportCrawler/result/20171229_2.txt

# %%
ma.trend_analysis("all")

# %%
ma.filtering_contents("기후")
ma.trend_analysis("climate")

# %%
# TF-IDF 기준
ma.keyword_analysis(200)
# Out:
# 9084
# Keyword Analysis
# [('국립공원', 254.94446154892447),
#  ('시설', 187.94245269868634),
#  ('조사', 172.38738516624161),
#  ('배출', 171.7095833936106),
#  ('생물', 170.80329959959616),
#  ('기술', 168.96586727088518),
#  ('자원', 150.3377484828536),
#  ('산업', 149.7752516338395),
#  ('연구', 148.88113410042158),
#  ('녹색', 145.54034441389103),
#  ('물질', 141.16217588616036),
#  ('공단', 139.10846923566814),
#  ('처리', 128.30002302467284),
#  ('기업', 127.62972413961629),
#  ('폐기물', 127.27645966794009),
#  ('생태', 126.92736877981503),
#  ('수질', 123.54385169616442),
#  ('평가', 118.47755353169323),
#  ('협력', 116.61153904145424),
#  ('온실가스', 113.10830850443567),
#  ('지원', 112.3340277088358),
#  ('국제', 111.14376470777229),
#  ('피해', 110.77059993818717),
#  ('기후변화', 107.74902427951619),
#  ('교육', 106.51946715340893),
#  ('제품', 105.24677629415345),
#  ('국내', 104.66458853417666),
#  ('개선', 104.13199599132763),
#  ('분야', 103.29487888389777),
#  ('정보', 103.23844602973546),
#  ('행사', 103.1831016204778),
#  ('협약', 103.14322254113434),
#  ('화학물질', 102.70897451858642),
#  ('개발', 100.26753215496333),
#  ('탐방', 97.5891109336751),
#  ('자연', 96.72574610325913),
#  ('기관', 96.2686947759685),
#  ('운영', 95.40340262486751),
#  ('친환경', 94.76273742784647),
#  ('보전', 93.8849471927701),
#  ('제도', 93.3514677871051),
#  ('시행', 93.13634304813083),
#  ('재활용', 92.5772397279812),
#  ('생태계', 92.1756370955836),
#  ('오염', 91.60987007702892),
#  ('국민', 91.1198379685294),
#  ('환경 산업', 90.34413367269673),
#  ('영향', 88.6400898433792),
#  ('국가', 88.3306911899541),
#  ('국립', 87.84875853268865),
#  ('공동', 87.1419457024757),
#  ('우리나라', 86.94656192310566),
#  ('공사', 86.72786591750231),
#  ('회의', 85.79023284130555),
#  ('방안', 85.58992064043089),
#  ('습지', 85.46715134586029),
#  ('식물', 85.40266907703018),
#  ('측정', 85.36323238584093),
#  ('전국', 83.9949004552466),
#  ('소음', 83.83077400583164),
#  ('업체', 83.49492233733189),
#  ('대기', 82.75871676361821),
#  ('안전', 81.19089615352492),
#  ('생물 자원', 81.13340869461462),
#  ('관리 공단', 80.33284870102796),
#  ('대책', 80.14657068314114),
#  ('정부', 79.22633297346519),
#  ('지정', 78.29499120636945),
#  ('복원', 78.20206161986168),
#  ('유해', 78.1936675434592),
#  ('세계', 77.58530024789758),
#  ('대응', 77.06672149573824),
#  ('에너지', 76.6718885966153),
#  ('환경과학', 76.52183210900914),
#  ('전문가', 75.66286877043542),
#  ('센터', 75.5458143861025),
#  ('인증', 75.43603018320711),
#  ('지자체', 75.37868179312748),
#  ('국립생물자원관', 75.25604326814086),
#  ('탄소', 75.1763091029487),
#  ('프로그램', 74.8642534169726),
#  ('점검', 73.44214284082189),
#  ('발생', 73.13006502978563),
#  ('주민', 73.10874633890514),
#  ('활동', 72.49619183481448),
#  ('자료', 72.48446651417248),
#  ('농도', 72.33190056106392),
#  ('미세먼지', 71.39858463758183),
#  ('건강', 71.24975057227655),
#  ('우수', 70.79381821394313),
#  ('감축', 70.78658774887127),
#  ('자동차', 70.05496156820193),
#  ('생활', 70.0122489424328),
#  ('하천', 69.48500922956124),
#  ('한국 환경', 69.44833294542586),
#  ('이상', 69.34962921595907),
#  ('국립 환경과학', 68.99583402560519),
#  ('국립공원 관리', 68.96026761280085),
#  ('하수', 68.69085204438873),
#  ('위원회', 68.53473281376016),
#  ('분석', 68.48683959660265),
#  ('생물다양성', 68.02291587567584),
#  ('사고', 67.8468532099523),
#  ('조류', 67.73395691435064),
#  ('홍보', 67.31835445044223),
#  ('사례', 66.13610452779302),
#  ('어린이', 65.56067998105809),
#  ('성장', 65.47110034242047),
#  ('공모전', 64.93135033571328),
#  ('초과', 64.69997564526498),
#  ('발전', 64.36733592122637),
#  ('구축', 64.30990311337608),
#  ('현장', 63.4030561681448),
#  ('공원', 63.28502837445365),
#  ('설치', 63.20117440709337),
#  ('협의', 62.87813258137357),
#  ('시스템', 62.25418787887266),
#  ('강화', 61.72281007489438),
#  ('사진', 61.57657179237319),
#  ('체계', 61.57010505451984),
#  ('서식', 61.20733601526952),
#  ('조성', 60.90609931138464),
#  ('중국', 60.81432026462526),
#  ('시범', 60.53519248208934),
#  ('억원', 60.52563929487936),
#  ('내용', 60.22291352227591),
#  ('쓰레기', 59.95367155706496),
#  ('현황', 59.517341296121955),
#  ('이용', 59.49771032447116),
#  ('효과', 59.22704927379199),
#  ('사회', 59.01071418497239),
#  ('서울', 58.95753464808659),
#  ('수도권', 58.82233450823216),
#  ('대기오염', 58.65900878447025),
#  ('녹색 성장', 58.23853487606594),
#  ('순환', 57.99569834892161),
#  ('개체', 57.83733706870016),
#  ('환경 정책', 57.719964943452),
#  ('에서', 57.6941385174371),
#  ('야생', 57.65524739933614),
#  ('년도', 57.515114967317785),
#  ('선정', 57.48737498438984),
#  ('사용', 57.26487163994692),
#  ('서비스', 56.89163196707158),
#  ('산업 기술', 56.8622649530086),
#  ('총회', 56.63865160676149),
#  ('업무', 56.49868540984297),
#  ('과정', 56.48276449662666),
#  ('체결', 56.403248147153555),
#  ('목표', 56.18391236604872),
#  ('참여', 55.76523691659649),
#  ('실천', 55.31190907299807),
#  ('단속', 55.19428004025718),
#  ('시장', 54.90567410039486),
#  ('전문', 54.43013801258653),
#  ('체험', 54.41904051947317),
#  ('마리', 54.375716041614766),
#  ('지난', 54.23843530003149),
#  ('도입', 54.1904309947188),
#  ('수준', 53.904420725446656),
#  ('설명', 53.77262955524611),
#  ('보건', 53.74135721012695),
#  ('대해', 53.70069956408213),
#  ('문화', 53.37261871864651),
#  ('국립생태원', 53.33943248871108),
#  ('올해', 53.315088015656585),
#  ('보호', 53.13797988248124),
#  ('조사 결과', 52.97431217641454),
#  ('단계', 52.912834429058464),
#  ('환경 관리', 52.77204608579315),
#  ('포럼', 52.47289719240907),
#  ('현재', 52.371724532956414),
#  ('확대', 52.134589194446356),
#  ('가스', 51.95591058931848),
#  ('환경기술', 51.83246946303584),
#  ('적극', 51.71573657613752),
#  ('방법', 51.57567169973784),
#  ('검사', 51.565430143257515),
#  ('기간', 51.15307386449835),
#  ('특별', 51.064569484949445),
#  ('평균', 50.18331657347527),
#  ('지리산', 49.75401266880451),
#  ('이하', 49.64174766397357),
#  ('토양', 49.61615879779009),
#  ('시험', 49.48823247267959),
#  ('주변', 49.311291821670245),
#  ('성과', 48.89177297124545),
#  ('경제', 48.81001007942143),
#  ('건설', 48.75485147403723),
#  ('환경 보건', 48.7420630298986),
#  ('수립', 48.55951024388456),
#  ('수도', 48.4640071181005),
#  ('향후', 48.36030083069527),
#  ('한편', 48.250329214255096),
#  ('단체', 48.15733027764483),
#  ('도시', 48.07266252241071),
#  ('과장', 48.012864721078195),
#  ('보급', 47.983457672598995),
#  ('낙동강', 47.80860386849232),
#  ('개정', 47.62041887927875)]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-7815475200f6> in <module>()
# ----> 1 split(ma.filtered_idx_result_df['date'],"-")
#
# NameError: name 'split' is not defined

# %%
ma.filtering_contents("기후변화")
ma.filtered_idx_result_df
# Out:
#            date                                         title  \
# 0    2015-01-08                    탄소중립제품 첫 등장…탄소성적표지 제도의 선진화
# 1    2015-01-15         온실가스 배출권 할당 대상업체 525개 중 243개 업체가 이의신청
# 2    2015-01-28                        온실가스 외부감축사업 상쇄제도 본격 시행
# 3    2015-02-02                     탄소배출량 산정하고 기후변화 대응에 참여해요!
# 4    2015-02-10               온실가스 배출권 670만KAU*, 예비분에서 추가적 할당
# 5    2015-02-24                         한국 기후변화 평가보고서 2014 발간
# 6    2015-02-24                       환경부, 배출권거래제 상쇄제도 설명회 개최
# 7    2015-03-04                   신기후체제 알리기 위해 정부·기업·민간단체 손잡다
# 8    2015-03-12  국립생물자원관, 신종 무척추동물 올챙이새우류를 포함한 3,000점 동물표본...
# 9    2015-03-17                   ‘미세먼지 대응 방문교실’이 초등학교로 찾아갑니다
# 10   2015-03-20                 물의 소중함 알린다…세계 물의 날 기념식 경주서 열려
# 11   2015-03-26                   꽃가루, 정확하게 구별하여 알레르기 피해 대비해요
# 12   2015-03-30                     행복도시, 친환경 분산식 빗물관리 시스템 도입
# 13   2015-04-03                 온실가스 1인 1톤 줄이기 조형물 서울시청 앞에 설치
# 14   2015-04-08                  세계 물 문제 해결에 아시아·태평양 대학생이 나선다
# 15   2015-04-09                      환경부, 친환경에너지타운 조성사업 본격 추진
# 16   2015-04-09                     생물산업의 블루오션, 거미 유전자원 확보 시작
# 17   2015-04-09                     「친환경에너지타운」사업 전국으로 본격 확산 !
# 18   2015-04-10                      한국, 유엔 지속가능소비·생산 신탁기금 출자
# 19   2015-04-10                  ‘탄소 빼기 숲 더하기’로 온실가스 감축을 실천해요
# 20   2015-04-12   세계물포럼…지속가능한 물관리와 생태계 보전, 물산업 활성화 촉진의 계기로...
# 21   2015-04-13                           제7차 세계물포럼 장관급 회의 개최
# 22   2015-04-14                          우리나라 생물다양성, 같이 찾아 봐요
# 23   2015-04-15                    고농도 오존 정보, 예보를 통해 미리 확인하세요
# 24   2015-04-16                  인간·자연 상생을 위한 수생태계…국제 심포지엄 개최
# 25   2015-04-17   환경부, 세계물포럼에서 지속가능한 물환경정책 발전과 물산업 활성화 청사진...
# 26   2015-04-20               ‘국립낙동강생물자원관의 설립 및 운영에 관한 법률’ 시행
# 27   2015-04-21                    친환경에너지타운 성공비결, 마을이장에게 배워요!
# 28   2015-04-22      ‘건강한 약속, 온실가스 1인 1톤 줄이기’제7회 기후변화주간 행사 개최
# 29   2015-04-24                          친환경소비하면 탄소상쇄 숲이 자랍니다
# ..          ...                                           ...
# 195  2017-07-26                      아고산대 침엽수에서 미기록 내생균 2종 발견
# 196  2017-08-01                   환경부, 무더운 여름 취약계층 건강 챙기기 나선다
# 197  2017-08-10           지속가능한 친환경 에너지로 전환, 전문가·시민사회의 지혜 모은다
# 198  2017-08-24    한·중·일 환경장관, 수원에서 미세먼지 대응과 지속가능발전목표 이행 등...
# 199  2017-08-24              가뭄대책, 기후변화에 맞춰 선제적·지역별 대응으로 전환한다
# 200  2017-08-25         한·중·일 환경장관, 동북아 미세먼지 등 환경문제 해결위해 의기투합
# 201  2017-08-31                   그린캠퍼스 25개 대학, 온실가스 감축에 앞장선다
# 202  2017-09-04            쓰레기 처리장에서 신재생에너지 메카로, 수도권매립지의 새 그림
# 203  2017-09-11                      환경부, 아시아 기후변화 적응 국제포럼 개최
# 204  2017-09-13                     도시공원, 열스트레스 등급 2단계 이상 낮춘다
# 205  2017-09-14                             담수생물 다양성의 미래를 논하다
# 206  2017-09-18                  세종·충북지역 도시 침수, 물관리 일원화로 해결한다
# 207  2017-09-20                          물산업 유망기술 보려면 경주에 오세요
# 208  2017-09-20                   대전·충남권 가뭄 해소, 물관리 일원화로 시작한다
# 209  2017-09-21                 대구·경북 맑고 깨끗한 물, 물관리 일원화로 앞당긴다
# 210  2017-09-25                        제32차 토양의 질 국제표준화 회의 개최
# 211  2017-09-25                    국립환경과학원, 제8차 환경위성 국제워크숍 개최
# 212  2017-10-12                미세먼지 대응 방안 토론을 위한 한-독 환경워크숍 개최
# 213  2017-10-16             멸종위기종 좀수수치, 다도해해상 고흥반도에서 집단서식지 발견
# 214  2017-10-18                    환경부-산업부, 지속가능한 미래를 위해 손잡는다
# 215  2017-10-25              한·중·일 환경과학원장 동북아시아 환경오염 연구 협력 강화
# 216  2017-10-26                       2018년 상반기 중으로 환경위성센터 신설
# 217  2017-11-01                   건강하고 안전한 착한소비…대한민국 친환경대전 개막
# 218  2017-11-06              파리협정 이행지침 마련을 위한 제23차 기후변화 총회 개막
# 219  2017-11-15                      환경부, 취약계층 따뜻한 겨울나기 방문서비스
# 220  2017-11-17                           생물다양성 미래의 주역이 한 자리에
# 221  2017-11-20               파리협정 이행지침 마련을 위한 기후총회(COP23) 폐막
# 222  2017-11-22                            구상나무 유전자 다양성, 양호하다
# 223  2017-11-30                        국립생태원, 한라산 중점생태연구지소 개소
# 224  2017-12-15             (참고) 중국, 대기개선에 대규모 투자…한국 기업 주목받는다
#
#                                       content_url_list  \
# 0    http://www.me.go.kr/home/web/board/read.do;jse...
# 1    http://www.me.go.kr/home/web/board/read.do;jse...
# 2    http://www.me.go.kr/home/web/board/read.do;jse...
# 3    http://www.me.go.kr/home/web/board/read.do;jse...
# 4    http://www.me.go.kr/home/web/board/read.do;jse...
# 5    http://www.me.go.kr/home/web/board/read.do;jse...
# 6    http://www.me.go.kr/home/web/board/read.do;jse...
# 7    http://www.me.go.kr/home/web/board/read.do;jse...
# 8    http://www.me.go.kr/home/web/board/read.do;jse...
# 9    http://www.me.go.kr/home/web/board/read.do;jse...
# 10   http://www.me.go.kr/home/web/board/read.do;jse...
# 11   http://www.me.go.kr/home/web/board/read.do;jse...
# 12   http://www.me.go.kr/home/web/board/read.do;jse...
# 13   http://www.me.go.kr/home/web/board/read.do;jse...
# 14   http://www.me.go.kr/home/web/board/read.do;jse...
# 15   http://www.me.go.kr/home/web/board/read.do;jse...
# 16   http://www.me.go.kr/home/web/board/read.do;jse...
# 17   http://www.me.go.kr/home/web/board/read.do;jse...
# 18   http://www.me.go.kr/home/web/board/read.do;jse...
# 19   http://www.me.go.kr/home/web/board/read.do;jse...
# 20   http://www.me.go.kr/home/web/board/read.do;jse...
# 21   http://www.me.go.kr/home/web/board/read.do;jse...
# 22   http://www.me.go.kr/home/web/board/read.do;jse...
# 23   http://www.me.go.kr/home/web/board/read.do;jse...
# 24   http://www.me.go.kr/home/web/board/read.do;jse...
# 25   http://www.me.go.kr/home/web/board/read.do;jse...
# 26   http://www.me.go.kr/home/web/board/read.do;jse...
# 27   http://www.me.go.kr/home/web/board/read.do;jse...
# 28   http://www.me.go.kr/home/web/board/read.do;jse...
# 29   http://www.me.go.kr/home/web/board/read.do;jse...
# ..                                                 ...
# 195  http://www.me.go.kr/home/web/board/read.do;jse...
# 196  http://www.me.go.kr/home/web/board/read.do;jse...
# 197  http://www.me.go.kr/home/web/board/read.do;jse...
# 198  http://www.me.go.kr/home/web/board/read.do;jse...
# 199  http://www.me.go.kr/home/web/board/read.do;jse...
# 200  http://www.me.go.kr/home/web/board/read.do;jse...
# 201  http://www.me.go.kr/home/web/board/read.do;jse...
# 202  http://www.me.go.kr/home/web/board/read.do;jse...
# 203  http://www.me.go.kr/home/web/board/read.do;jse...
# 204  http://www.me.go.kr/home/web/board/read.do;jse...
# 205  http://www.me.go.kr/home/web/board/read.do;jse...
# 206  http://www.me.go.kr/home/web/board/read.do;jse...
# 207  http://www.me.go.kr/home/web/board/read.do;jse...
# 208  http://www.me.go.kr/home/web/board/read.do;jse...
# 209  http://www.me.go.kr/home/web/board/read.do;jse...
# 210  http://www.me.go.kr/home/web/board/read.do;jse...
# 211  http://www.me.go.kr/home/web/board/read.do;jse...
# 212  http://www.me.go.kr/home/web/board/read.do;jse...
# 213  http://www.me.go.kr/home/web/board/read.do;jse...
# 214  http://www.me.go.kr/home/web/board/read.do;jse...
# 215  http://www.me.go.kr/home/web/board/read.do;jse...
# 216  http://www.me.go.kr/home/web/board/read.do;jse...
# 217  http://www.me.go.kr/home/web/board/read.do;jse...
# 218  http://www.me.go.kr/home/web/board/read.do;jse...
# 219  http://www.me.go.kr/home/web/board/read.do;jse...
# 220  http://www.me.go.kr/home/web/board/read.do;jse...
# 221  http://www.me.go.kr/home/web/board/read.do;jse...
# 222  http://www.me.go.kr/home/web/board/read.do;jse...
# 223  http://www.me.go.kr/home/web/board/read.do;jse...
# 224  http://www.me.go.kr/home/web/board/read.do;jse...
#
#                                         file_list
# 0    /media/MeReportCrawler/result/20150108_1.txt
# 1    /media/MeReportCrawler/result/20150115_1.txt
# 2    /media/MeReportCrawler/result/20150128_2.txt
# 3    /media/MeReportCrawler/result/20150202_1.txt
# 4    /media/MeReportCrawler/result/20150210_1.txt
# 5    /media/MeReportCrawler/result/20150224_1.txt
# 6    /media/MeReportCrawler/result/20150224_2.txt
# 7    /media/MeReportCrawler/result/20150304_1.txt
# 8    /media/MeReportCrawler/result/20150312_1.txt
# 9    /media/MeReportCrawler/result/20150317_1.txt
# 10   /media/MeReportCrawler/result/20150320_3.txt
# 11   /media/MeReportCrawler/result/20150326_4.txt
# 12   /media/MeReportCrawler/result/20150330_3.txt
# 13   /media/MeReportCrawler/result/20150403_3.txt
# 14   /media/MeReportCrawler/result/20150408_3.txt
# 15   /media/MeReportCrawler/result/20150409_1.txt
# 16   /media/MeReportCrawler/result/20150409_2.txt
# 17   /media/MeReportCrawler/result/20150409_4.txt
# 18   /media/MeReportCrawler/result/20150410_3.txt
# 19   /media/MeReportCrawler/result/20150410_2.txt
# 20   /media/MeReportCrawler/result/20150412_1.txt
# 21   /media/MeReportCrawler/result/20150413_1.txt
# 22   /media/MeReportCrawler/result/20150414_2.txt
# 23   /media/MeReportCrawler/result/20150415_2.txt
# 24   /media/MeReportCrawler/result/20150416_2.txt
# 25   /media/MeReportCrawler/result/20150417_2.txt
# 26   /media/MeReportCrawler/result/20150420_3.txt
# 27   /media/MeReportCrawler/result/20150421_1.txt
# 28   /media/MeReportCrawler/result/20150422_1.txt
# 29   /media/MeReportCrawler/result/20150424_1.txt
# ..                                            ...
# 195  /media/MeReportCrawler/result/20170726_1.txt
# 196  /media/MeReportCrawler/result/20170801_3.txt
# 197  /media/MeReportCrawler/result/20170810_2.txt
# 198  /media/MeReportCrawler/result/20170824_3.txt
# 199  /media/MeReportCrawler/result/20170824_1.txt
# 200  /media/MeReportCrawler/result/20170825_2.txt
# 201  /media/MeReportCrawler/result/20170831_3.txt
# 202  /media/MeReportCrawler/result/20170904_5.txt
# 203  /media/MeReportCrawler/result/20170911_1.txt
# 204  /media/MeReportCrawler/result/20170913_1.txt
# 205  /media/MeReportCrawler/result/20170914_1.txt
# 206  /media/MeReportCrawler/result/20170918_2.txt
# 207  /media/MeReportCrawler/result/20170920_2.txt
# 208  /media/MeReportCrawler/result/20170920_3.txt
# 209  /media/MeReportCrawler/result/20170921_1.txt
# 210  /media/MeReportCrawler/result/20170925_1.txt
# 211  /media/MeReportCrawler/result/20170925_7.txt
# 212  /media/MeReportCrawler/result/20171012_3.txt
# 213  /media/MeReportCrawler/result/20171016_4.txt
# 214  /media/MeReportCrawler/result/20171018_3.txt
# 215  /media/MeReportCrawler/result/20171025_5.txt
# 216  /media/MeReportCrawler/result/20171026_6.txt
# 217  /media/MeReportCrawler/result/20171101_4.txt
# 218  /media/MeReportCrawler/result/20171106_3.txt
# 219  /media/MeReportCrawler/result/20171115_3.txt
# 220  /media/MeReportCrawler/result/20171117_1.txt
# 221  /media/MeReportCrawler/result/20171120_4.txt
# 222  /media/MeReportCrawler/result/20171122_2.txt
# 223  /media/MeReportCrawler/result/20171130_1.txt
# 224  /media/MeReportCrawler/result/20171215_2.txt
#
# [225 rows x 4 columns]

# %%
#ma.select_topic([3])
#ma.filtered_idx_result_df

# %%
a = pd.read_csv("./tm_result/result_n_22_s1_topic_words.csv",header=None,index_col=None)

# %%
#a.iloc[:,21:25]
a
# Out:
#            0        1        2        3        4     5     6       7      8   \
# 0          포장    정부 포상       철새     국립공원      쓰레기    시설  화학물질     공모전     협력
# 1          운전       마당       이동       탐방      음식물    수질    제품      작품     녹색
# 2      친환경 운전       포상    이동 경로       공단  음식물 쓰레기    배출    제도     어린이     회의
# 3         친환경       물의       경로  국립공원 공단       음식    처리    인증      질환     세계
# 4          과대       기념    철새 이동       습지      종량제    물질    정보      보건   기후변화
# 5         포장재    포상 수여    철새 센터       공원       수거    오염    안전     수상작     포럼
# 6          선물    휴식 공간       홍도      지리산    음식 문화    하수    시행      공모     성장
# 7          임원       포장       부착       자연   쓰레기 수거    측정    유해    아이디어  녹색 성장
# 8   수도권매립지 공사       휴식      장거리       생태       용기    개선   친환경  환경성 질환     공동
# 9      수도권매립지     국무총리   장거리 이동       북한       연휴  온실가스    업체      상금     발전
# 10         주행       유공       중국       복원       반환    하천    기관      부문     교육
# 11         연비   대통령 표창       추적       해상  쓰레기 종량제    대책    녹색      심사     방안
# 12         명절       공간       일본       경관       청소    농도   서비스      선정     협약
# 13         약력       표창       센터       보전       봉투   지자체   시스템      접수     국가
# 14         연료    보전 협력  대기오염 물질       마리       투기    영향    물질  사진 공모전  생물다양성
# 15         단속  국무총리 표창       월동      설악산       감량    억원    개정      석면     정부
# 16         선발       방치       조류   공단 이사장    수거 처리    대기    시험      사랑     논의
# 17         추석    정화 활동      동북아      이사장    문화 개선    운영    규제     청소년     주제
# 18         대회       시민       대만       서식       인상   에너지    등록      수상     보전
# 19         식품       시책      신안군       계곡      휴게소  대기오염    협약     환경성    아시아
#
#          9    ...        12      13       14       15       16      17  \
# 0     국립생태원   ...        비점     폐기물       생물       조류       인사      실천
# 1        체험   ...     비점 오염     재활용    생물 자원      남조류    인사 발령      녹색
# 2        교육   ...    비점 오염원      자원  국립생물자원관       정수     보도자료     캠페인
# 3        생태   ...        채용      순환       식물       지오       과장      그린
# 4      생태관광   ...        기구   자원 순환       자원       발령  발령 보도자료   녹색 생활
# 5      프로그램   ...     양성 과정      처리       자생       냄새       발령      생활
# 6       어린이   ...       오염원      공사      생태계       세포       일자    온실가스
# 7        가족   ...        근무      광산       서식      팔당호      대변인      탄소
# 8        학교   ...        모집      배출       개체      주의보       관실      운동
# 9       청소년   ...        석사      토양       야생       창업       전보     스타트
# 10       전시   ...        양성      소각     멸종위기    조류 발생       승진  그린 스타트
# 11       문화   ...        수료    토양오염      유전자       호소       국장   생활 실천
# 12       자연   ...        선발   자원 공사    생물다양성       상수       기획     휴대폰
# 13      전시관   ...        파견      매립       곤충       녹조       유역      수거
# 14       에코   ...        과정  폐기물 처리       표본  모니터링 결과    전보 일자    층간소음
# 15    반달가슴곰   ...        인재      품질       보전       원수  보도자료 과장     포인트
# 16       학생   ...        면접      회수       조류     모니터링    과장 전보      홍보
# 17      관람객   ...        영어     주유소    자생 생물       북한   고위 공무원      감축
# 18  교육 프로그램   ...      전문교육      감량       독도       출현       한강     친환경
# 19       사랑   ...        성적  건설 폐기물      서식지    감소 추세  한강유역환경청     자전거
#
#          18        19     20      21
# 0      기후변화       자동차     단속      소음
# 1        시장      미세먼지     점검      분쟁
# 2        감축     배출 가스     위반      배상
# 3      온실가스        가스     적발   분쟁 조정
# 4        진출        예보     배출      공사
# 5        적응        차량     시설      조정
# 6        중국        배출     특별      진동
# 7       베트남       수도권     폐수  조정 위원회
# 8   온실가스 감축        경유     불법   중앙 분쟁
# 9        협상        충전     행위      신청
# 10       협력        대기     처리     아파트
# 11    시장 진출       전기차     기지      사건
# 12      개도국        결함    골프장      결정
# 13  기후변화 적응  수도권대기환경청     업체   소음 진동
# 14       수주        차종  특별 점검     위원회
# 15     프로젝트        운행  배출 시설      중앙
# 16  기후변화 협약        공해     감시      정신
# 17  기후변화 대응        검사     조치   공사 소음
# 18       체제        등급   환경오염   배상 결정
# 19       현지       제작사     신고      도로
#
# [20 rows x 22 columns]
